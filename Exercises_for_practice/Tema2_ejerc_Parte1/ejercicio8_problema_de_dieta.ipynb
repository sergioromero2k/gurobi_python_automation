# %% [markdown]
# ## Ejercicio 8 - Problema de dieta
#
# Un veterinario quiere elaborar un compuesto que permita alimentar a los chimpanses y que cubra sus necesidades mínimas de calcio, fósforo y magnesio al mínimo coste posible. Para ello se debe mezclar de forma adecuada dos preparados alimenticios, A y B. Una porción de A contiene 30 mg de calcio, 10 mg de fósforo y 40 mg de magnesio, y cuesta 3 euros. Mientras que una porción de B contiene 40 mg de calcio, 30 mg de fósforo y 20 mg de magnesio, y tiene un precio de 4 euros.
#
# Si la dieta debe aportar, al menos 450 mg de calcio, 150 mg de fósforo y 300 mg de magnesio, ¿cuántas porciones de cada preparado deben utilizarse para satisfacer estos requisitos con el mínimo coste? ¿ En estos casos el chimpanse recibirá más cantidad de calcio que la necesaria?

# %% [markdown]
# |               | Calcio (mg) | Fósforo (mg) | Magnesio (mg) | Coste (€/u) |
# |---------------|------------|-------------|---------------|-------------|
# | Preparado A (x1) | 30         | 10          | 40            | 3           |
# | Preparado B (x2) | 40         | 30          | 20            | 4           |
# | Cantidades mínimas | 450        | 150         | 300           | -           |
#
#
# #### Trucos propios (VA-FU-RE^3)
# - Variables de Decisión
# - Función objetivo
# - Restricciones de Oferta
# - Restricciones de Demanda
# - Restricciones de Dominio
# \(x_1\)
#
# $$3x\_1 + 2x\_2 \\le 40

# %%
# Import the library
from gurobipy import *
